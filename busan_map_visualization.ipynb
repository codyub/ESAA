# %% [markdown]
# <a href="https://colab.research.google.com/github/codyub/ESAA/blob/main/busan_map_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font', family='NanumBarunGothic') #matplotlib 한글 깨짐 방지

import warnings
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir("/content/drive/MyDrive/ESAA/프로젝트4_부산/")
# Out:
# Mounted at /content/drive

# %%
 data = pd.read_csv('공공포털_상가_상권_정보_2020-09.txt', sep = "|")

# %%
data.head()
# Out:
#    sopsrt_bssh_no  cmpnm_nm bhf_nm trdar_induty_lclas_code  \
# 0        19912201  싱싱커피&토스트    NaN                       Q
# 1        20031733  동해제일산오징어    NaN                       Q
# 2        20033259    리지호프소주    NaN                       Q
# 3        20047434    경부할인마트    NaN                       D
# 4        20037352       마니쩜    NaN                       Q
#
#   trdar_induty_lclas_nm trdar_induty_mlsfc_code trdar_induty_mlsfc_nm  \
# 0                    음식                     Q07                 패스트푸드
# 1                    음식                     Q03                일식/수산물
# 2                    음식                     Q06                    양식
# 3                    소매                     D03                 종합소매점
# 4                    음식                     Q09                  유흥주점
#
#   trdar_induty_sclas_code trdar_induty_sclas_nm std_indust_cl_code  ...  \
# 0                  Q07A10                 토스트전문             I56192  ...
# ...

# %%
data.iloc[:,14] # 구에 대한 정보는 14열에 존재함
# Out:
# 0          사상구
# 1          동래구
# 2         부산진구
# 3           동구
# 4         부산진구
#           ...
# 153971      중구
# 153972    해운대구
# 153973     사하구
# 153974     강서구
# 153975     사상구
# Name: signgu_nm, Length: 153976, dtype: object

# %%
data.groupby('trdar_induty_mlsfc_nm').count()
# Out:
#                        sopsrt_bssh_no  cmpnm_nm  bhf_nm  \
# trdar_induty_mlsfc_nm
# PC/오락/당구/볼링등                     1409      1409     214
# 가구소매                              908       908     127
# 가방/신발/액세서리                       3102      3101     263
# 가전제품소매                            783       783     282
# 가정/주방/인테리어                       5028      5028     152
# ...                               ...       ...     ...
# 학원기타                             1810      1810     138
# 한식                              17854     17854    1664
# 행사/이벤트                            100       100       1
# 호텔/콘도                             386       386      29
# 화장품소매                            2828      2828     769
#
#                        trdar_induty_lclas_code  trdar_induty_lclas_nm  \
# trdar_induty_mlsfc_nm
# PC/오락/당구/볼링등                              1409                   1409
# 가구소매                                       908                    908
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153976 entries, 0 to 153975
# Data columns (total 40 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   sopsrt_bssh_no           153976 non-null  int64
#  1   cmpnm_nm                 153975 non-null  object
#  2   bhf_nm                   19193 non-null   object
#  3   trdar_induty_lclas_code  153976 non-null  object
#  4   trdar_induty_lclas_nm    153976 non-null  object
#  5   trdar_induty_mlsfc_code  153976 non-null  object
#  6   trdar_induty_mlsfc_nm    153976 non-null  object
#  7   trdar_induty_sclas_code  153976 non-null  object
#  8   trdar_induty_sclas_nm    153976 non-null  object
#  9   std_indust_cl_code       144359 non-null  object
#  10  std_indust_cl_nm         144359 non-null  object
#  11  ctprvn_code              153976 non-null  int64
#  12  ctprvn_nm                153976 non-null  object
# ...

# %%
cafe = data[data['trdar_induty_mlsfc_nm']== '커피점/카페']

# %%
cafe.groupby('signgu_nm').count()
# Out:
#            sopsrt_bssh_no  cmpnm_nm  bhf_nm  trdar_induty_lclas_code  \
# signgu_nm
# 강서구                   249       249      92                      249
# 금정구                   426       426     130                      426
# 기장군                   359       359     115                      359
# 남구                    365       365     110                      365
# 동구                    224       224      69                      224
# 동래구                   373       373     139                      373
# 부산진구                  743       743     252                      743
# 북구                    249       249      83                      249
# 사상구                   274       274      68                      274
# 사하구                   320       320     113                      320
# 서구                    159       159      55                      159
# 수영구                   391       391     127                      391
# ...

# %%
cafe['signgu_nm'].value_counts()
# Out:
# 부산진구    743
# 해운대구    682
# 금정구     426
# 수영구     391
# 동래구     373
# 남구      365
# 기장군     359
# 사하구     320
# 중구      319
# 사상구     274
# 연제구     265
# 북구      249
# 강서구     249
# 동구      224
# 영도구     169
# 서구      159
# Name: signgu_nm, dtype: int64

# %%
for i in cafe['signgu_nm'].value_counts() :
  print(i)
# Out:
# 743
# 682
# 426
# 391
# 373
# 365
# 359
# 320
# 319
# 274
# 265
# 249
# 249
# 224
# 169
# 159

# %%
# m = folium.Map(location = [35.1795543, 129.0756416], zoom_start = 14)
# m

# %%
from branca.element import Figure

# %%
fig = Figure(width=2000,height=1200)
m = folium.Map(location=[35.1795543, 129.0756416], 
               zoom_start=13)
fig.add_child(m)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 부산 진구
folium.CircleMarker(
    [35.16, 129.05],
    radius=74.3,
    fill=False,
).add_to(m)

# 부산 해운대구
folium.CircleMarker(
    [35.16, 129.16],
    radius=68.2,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 금정구     426
folium.CircleMarker(
    [35.24, 129.09],
    radius=42.6,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 수영구     391
folium.CircleMarker(
    [35.15, 129.11],
    radius=39.1,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 동래구     373
folium.CircleMarker(
    [35.20, 129.08],
    radius=37.3,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 남구      365
folium.CircleMarker(
    [35.14, 129.08],
    radius=36.5,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 기장군     359
folium.CircleMarker(
    [35.24, 129.22],
    radius=35.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 사하구     320
folium.CircleMarker(
    [35.10, 128.97],
    radius=32,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 중구      319
folium.CircleMarker(
    [35.11, 129.03],
    radius=31.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 사상구     274
folium.CircleMarker(
    [35.15, 128.99],
    radius=27.4,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 연제구     265
folium.CircleMarker(
    [35.18, 129.08],
    radius=26.5,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 북구      249
folium.CircleMarker(
    [35.20, 128.99],
    radius=24.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 강서구     249
folium.CircleMarker(
    [35.21, 128.98],
    radius=24.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 동구      224
folium.CircleMarker(
    [35.14, 129.06],
    radius=22.4,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 영도구     169
folium.CircleMarker(
    [35.09, 129.07],
    radius=16.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

# 부산 서구      159
folium.CircleMarker(
    [35.10, 129.02],
    radius=15.9,
    fill=True,
    popup='popup',
    tooltip='tooltip'
).add_to(m)

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
